# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanmaigottumukkala/Thanmaigottumukkala/blob/main/ICP1_DataPreProcessingFilteration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In today's ICP, we will go over some basic data preprocessing steps using the pandas library. Preprocessing is the process of doing a pre-analysis of data, in order to transform them into a standard and normalized format.
#
# **ICP Summary**
#
# 1) Creating empty DataFrames and adding data to it.
#
# 2) Reading hapititis Dataset from Github.
#
# 3) Performing Data preprocessing and filteration steps on the dataset:
#
#
# >a) Performing assignment 1 task on this dataset.
#
# >b) checking the unique values for a column
#
# >c)Finding  missing Values
#
# >d) Dropping Missing values (Dataframe level)
#
# >e) df inplace function
#
# >f) Dropping Missing values (Series level)
#
# >g) Keeping the columns that have certain percentage of data
#
# >h) Pandas value_counts function for checking class distribution
#
# >i) Pandas .plot funtion to plot data

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# One of the question last time was how to create an empty dataframe and populate it with data?
#
# So below we will first create an empty dataframe and then in the following cell will populate it with some data.

# %%
df_empty= pd.DataFrame()
print(df_empty)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# lets populate this empty dataframe with some data

# %%
# append columns and their respective values to an empty DataFrame
df_empty['Class'] = ['Big Data', 'Python', 'OCEL.AI_Training']
df_empty['No_of_Sessions'] = [1, 3, 2]
df_empty['Enrolled_students'] = [20, 50,35]
df_empty
# Out:
#               Class  No_of_Sessions  Enrolled_students
# 0          Big Data               1                 20
# 1            Python               3                 50
# 2  OCEL.AI_Training               2                 35

# %% [markdown]
# 2nd method of creating empty dataframe with column names only and then add data to it.

# %%
# create an Empty DataFrame object With column names and indices
df_empty_2 = pd.DataFrame(columns = ['Class', 'No_of_Sessions', 'Enrolled_students'],
                   index = ['a', 'b', 'c'])

print("The dataframe wiht empty (NaN) values: \n\n")
df_empty_2
# Out:
# The dataframe wiht empty (NaN) values:
#   Class No_of_Sessions Enrolled_students
# a   NaN            NaN               NaN
# b   NaN            NaN               NaN
# c   NaN            NaN               NaN

# %% [markdown]
# Now add data row wise

# %%
# adding rows to an empty dataframe at existing index
df_empty_2.loc[1] = ['Big Data', 1, 20]
df_empty_2.loc[2] = ['Python', 3, 50]
df_empty_2.loc[3] = ['OCEL.AI_Training', 2, 35]



df_empty_2
# Out:
#               Class No_of_Sessions Enrolled_students
# a               NaN            NaN               NaN
# b               NaN            NaN               NaN
# c               NaN            NaN               NaN
# 1          Big Data              1                20
# 2            Python              3                50
# 3  OCEL.AI_Training              2                35

# %% [markdown]
# Lets read another dataset (hepatitis dataset)  from Github and lets do the assignment 1 tasks on it

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasets/hepatitis/master/data/hepatitis.csv')
df.head(10)
# Out:
#    age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0   30    male   False       False   False   False    False     False
# 1   50  female   False       False    True   False    False     False
# 2   78  female    True       False    True   False    False      True
# 3   31  female     NaN        True   False   False    False      True
# 4   34  female    True       False   False   False    False      True
# 5   34  female    True       False   False   False    False      True
# 6   51  female   False       False    True   False     True      True
# 7   23  female    True       False   False   False    False      True
# 8   39  female    True       False    True   False    False      True
# 9   30  female    True       False   False   False    False      True
#
#   liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0      False           False   False   False   False        1.0
# 1      False           False   False   False   False        0.9
# 2      False           False   False   False   False        0.7
# 3      False           False   False   False   False        0.7
# 4      False           False   False   False   False        1.0
# 5      False           False   False   False   False        0.9
# 6      False            True    True   False   False        NaN
# 7      False           False   False   False   False        1.0
# 8       True           False   False   False   False        0.7
# 9      False           False   False   False   False        1.0
#
#    alk_phosphate   sgot  albumin  protime  histology class
# 0           85.0   18.0      4.0      NaN      False  live
# 1          135.0   42.0      3.5      NaN      False  live
# 2           96.0   32.0      4.0      NaN      False  live
# 3           46.0   52.0      4.0     80.0      False  live
# 4            NaN  200.0      4.0      NaN      False  live
# 5           95.0   28.0      4.0     75.0      False  live
# 6            NaN    NaN      NaN      NaN      False   die
# 7            NaN    NaN      NaN      NaN      False  live
# 8            NaN   48.0      4.4      NaN      False  live
# 9            NaN  120.0      3.9      NaN      False  live

# %% [markdown]
# lets look at the size of data (number of rows and columns)

# %%
df.shape
# Out:
# (155, 20)

# %% [markdown]
# **a) Performing assignment 1 task on this dataset (Data filteration and preprocessing).**
#
# Now we will split the data into numeric and categorical columns.
#
# First,  we will create a numeric dataframe from our original dataframe (df)

# %%
numeric_df = df.select_dtypes(include=np.number).copy()
numeric_df
# Out:
#      age  bilirubin  alk_phosphate   sgot  albumin  protime
# 0     30        1.0           85.0   18.0      4.0      NaN
# 1     50        0.9          135.0   42.0      3.5      NaN
# 2     78        0.7           96.0   32.0      4.0      NaN
# 3     31        0.7           46.0   52.0      4.0     80.0
# 4     34        1.0            NaN  200.0      4.0      NaN
# ..   ...        ...            ...    ...      ...      ...
# 150   46        7.6            NaN  242.0      3.3     50.0
# 151   44        0.9          126.0  142.0      4.3      NaN
# 152   61        0.8           75.0   20.0      4.1      NaN
# 153   53        1.5           81.0   19.0      4.1     48.0
# 154   43        1.2          100.0   19.0      3.1     42.0
#
# [155 rows x 6 columns]

# %% [markdown]
# lets verify that all the columns in numeric_df has the right datatypes

# %%
numeric_df.dtypes
# Out:
# age                int64
# bilirubin        float64
# alk_phosphate    float64
# sgot             float64
# albumin          float64
# protime          float64
# dtype: object

# %% [markdown]
# Finding the mean of the numerical colummns can be found as:

# %%
numeric_df.mean()
# Out:
# age               41.200000
# bilirubin          1.427517
# alk_phosphate    105.325397
# sgot              85.894040
# albumin            3.817266
# protime           61.852273
# dtype: float64

# %% [markdown]
# Now, we will create a catagorical dataframe from our original dataframe (df)

# %%
categorical_df = df.select_dtypes(exclude=np.number).copy()
categorical_df
# Out:
#         sex steroid  antivirals fatigue malaise anorexia liver_big liver_firm  \
# 0      male   False       False   False   False    False     False      False
# 1    female   False       False    True   False    False     False      False
# 2    female    True       False    True   False    False      True      False
# 3    female     NaN        True   False   False    False      True      False
# 4    female    True       False   False   False    False      True      False
# ..      ...     ...         ...     ...     ...      ...       ...        ...
# 150  female    True       False    True    True     True      True      False
# 151  female    True       False    True   False    False      True       True
# 152  female   False       False    True    True    False     False       True
# 153    male   False       False    True   False    False      True      False
# 154  female    True       False    True   False    False      True      False
#
#     spleen_palpable spiders ascites varices  histology class
# 0             False   False   False   False      False  live
# 1             False   False   False   False      False  live
# 2             False   False   False   False      False  live
# 3             False   False   False   False      False  live
# 4             False   False   False   False      False  live
# ..              ...     ...     ...     ...        ...   ...
# 150           False    True    True    True       True   die
# 151           False   False   False   False       True  live
# 152           False    True   False   False       True  live
# 153            True    True   False    True       True  live
# 154            True    True    True   False       True   die
#
# [155 rows x 14 columns]

# %% [markdown]
# verifying the dataypes of each column in categorical dataset

# %%
categorical_df.dtypes
# Out:
# sex                object
# steroid            object
# antivirals           bool
# fatigue            object
# malaise            object
# anorexia           object
# liver_big          object
# liver_firm         object
# spleen_palpable    object
# spiders            object
# ascites            object
# varices            object
# histology            bool
# class              object
# dtype: object

# %% [markdown]
# Let's check the unique values for each of the categorical data
#
# ![Capture.PNG](data:image/png;base64,...)

# %%
categorical_df.nunique(axis=0)
# Out:
# sex                2
# steroid            2
# antivirals         2
# fatigue            2
# malaise            2
# anorexia           2
# liver_big          2
# liver_firm         2
# spleen_palpable    2
# spiders            2
# ascites            2
# varices            2
# histology          2
# class              2
# dtype: int64

# %% [markdown]
# checking unique values for a certain column (series level operation)

# %%
df['steroid'].unique()
# Out:
# array([False, True, nan], dtype=object)

# %% [markdown]
# **b) Handling Missing Values**
#
# Lets find out the missing values in the original hapititus dataset (df)
#
# In order to check whether our dataset contains missing values, we can use the function isna(), which returns if an cell of the dataset if NaN (missing value) or not. Then we can count how many missing values there are for each column(.sum() function).

# %%
df.isna().sum()
# Out:
# age                 0
# sex                 0
# steroid             1
# antivirals          0
# fatigue             1
# malaise             1
# anorexia            1
# liver_big          10
# liver_firm         11
# spleen_palpable     5
# spiders             5
# ascites             5
# varices             5
# bilirubin           6
# alk_phosphate      29
# sgot                4
# albumin            16
# protime            67
# histology           0
# class               0
# dtype: int64

# %% [markdown]
# Now we can count the percentage of missing values for each column, simply by dividing the previous result by the length of the dataset (len(df)) and multiplying per 100.

# %%
(df.isna().sum()/len(df))*100
# Out:
# age                 0.000000
# sex                 0.000000
# steroid             0.645161
# antivirals          0.000000
# fatigue             0.645161
# malaise             0.645161
# anorexia            0.645161
# liver_big           6.451613
# liver_firm          7.096774
# spleen_palpable     3.225806
# spiders             3.225806
# ascites             3.225806
# varices             3.225806
# bilirubin           3.870968
# alk_phosphate      18.709677
# sgot                2.580645
# albumin            10.322581
# protime            43.225806
# histology           0.000000
# class               0.000000
# dtype: float64

# %% [markdown]
# When dealing with missing values, different alternatives can be applied:
#
# 1)check the source, for example by contacting the data source to correct the missing values
#
# 2)drop missing values
#
# 3)replace the missing value with a value
#
# 4) leave the missing value as it is.
#
# Lets start by looking into dropping the missing values
#
# a) Droping rows  (axis=0)
#
# b) Dropping the columns (axis=1)

# %%
# dropping the columns with missing values
df.dropna(axis=1)
# Out:
#      age     sex  antivirals  histology class
# 0     30    male       False      False  live
# 1     50  female       False      False  live
# 2     78  female       False      False  live
# 3     31  female        True      False  live
# 4     34  female       False      False  live
# ..   ...     ...         ...        ...   ...
# 150   46  female       False       True   die
# 151   44  female       False       True  live
# 152   61  female       False       True  live
# 153   53    male       False       True  live
# 154   43  female       False       True   die
#
# [155 rows x 5 columns]

# %%
df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0        False           False   False   False   False        1.0
# 1        False           False   False   False   False        0.9
# 2        False           False   False   False   False        0.7
# 3        False           False   False   False   False        0.7
# 4        False           False   False   False   False        1.0
# ..         ...             ...     ...     ...     ...        ...
# 150      False           False    True    True    True        7.6
# 151       True           False   False   False   False        0.9
# 152       True           False    True   False   False        0.8
# 153      False            True    True   False    True        1.5
# 154      False            True    True    True   False        1.2
#
#      alk_phosphate   sgot  albumin  protime  histology class
# 0             85.0   18.0      4.0      NaN      False  live
# 1            135.0   42.0      3.5      NaN      False  live
# 2             96.0   32.0      4.0      NaN      False  live
# 3             46.0   52.0      4.0     80.0      False  live
# 4              NaN  200.0      4.0      NaN      False  live
# ..             ...    ...      ...      ...        ...   ...
# 150            NaN  242.0      3.3     50.0       True   die
# 151          126.0  142.0      4.3      NaN       True  live
# 152           75.0   20.0      4.1      NaN       True  live
# 153           81.0   19.0      4.1     48.0       True  live
# 154          100.0   19.0      3.1     42.0       True   die
#
# [155 rows x 20 columns]

# %%
# dropping the rows with missing values
df.dropna(axis=0)
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 5     34  female    True       False   False   False    False      True
# 10    39  female   False        True   False   False    False     False
# 11    32  female    True        True    True   False    False      True
# 12    41  female    True        True    True   False    False      True
# 13    30  female    True       False    True   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 139   45  female    True        True   False   False    False      True
# 143   49  female   False       False    True    True    False      True
# 145   31  female   False       False    True   False    False      True
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 5        False           False   False   False   False        0.9
# 10        True           False   False   False   False        1.3
# 11        True           False    True   False   False        1.0
# 12        True           False   False   False   False        0.9
# 13        True           False   False   False   False        2.2
# ..         ...             ...     ...     ...     ...        ...
# 139      False           False   False   False   False        1.3
# 143      False            True    True   False   False        1.4
# 145      False           False   False   False   False        1.2
# 153      False            True    True   False    True        1.5
# 154      False            True    True    True   False        1.2
#
#      alk_phosphate   sgot  albumin  protime  histology class
# 5             95.0   28.0      4.0     75.0      False  live
# 10            78.0   30.0      4.4     85.0      False  live
# 11            59.0  249.0      3.7     54.0      False  live
# 12            81.0   60.0      3.9     52.0      False  live
# 13            57.0  144.0      4.9     78.0      False  live
# ..             ...    ...      ...      ...        ...   ...
# 139           85.0   44.0      4.2     85.0       True  live
# 143           85.0   70.0      3.5     35.0       True   die
# 145           75.0  173.0      4.2     54.0       True  live
# 153           81.0   19.0      4.1     48.0       True  live
# 154          100.0   19.0      3.1     42.0       True   die
#
# [80 rows x 20 columns]

# %%
df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0        False           False   False   False   False        1.0
# 1        False           False   False   False   False        0.9
# 2        False           False   False   False   False        0.7
# 3        False           False   False   False   False        0.7
# 4        False           False   False   False   False        1.0
# ..         ...             ...     ...     ...     ...        ...
# 150      False           False    True    True    True        7.6
# 151       True           False   False   False   False        0.9
# 152       True           False    True   False   False        0.8
# 153      False            True    True   False    True        1.5
# 154      False            True    True    True   False        1.2
#
#      alk_phosphate   sgot  albumin  protime  histology class
# 0             85.0   18.0      4.0      NaN      False  live
# 1            135.0   42.0      3.5      NaN      False  live
# 2             96.0   32.0      4.0      NaN      False  live
# 3             46.0   52.0      4.0     80.0      False  live
# 4              NaN  200.0      4.0      NaN      False  live
# ..             ...    ...      ...      ...        ...   ...
# 150            NaN  242.0      3.3     50.0       True   die
# 151          126.0  142.0      4.3      NaN       True  live
# 152           75.0   20.0      4.1      NaN       True  live
# 153           81.0   19.0      4.1     48.0       True  live
# 154          100.0   19.0      3.1     42.0       True   die
#
# [155 rows x 20 columns]

# %% [markdown]
# Note, removed values are not applied to the original dataframe, but only to the result. We can use the argument inplace=True in order to store changes in the original dataframe (df.dropna(axis=1,inplace=True)).

# %%
df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0        False           False   False   False   False        1.0
# 1        False           False   False   False   False        0.9
# 2        False           False   False   False   False        0.7
# 3        False           False   False   False   False        0.7
# 4        False           False   False   False   False        1.0
# ..         ...             ...     ...     ...     ...        ...
# 150      False           False    True    True    True        7.6
# 151       True           False   False   False   False        0.9
# 152       True           False    True   False   False        0.8
# 153      False            True    True   False    True        1.5
# 154      False            True    True    True   False        1.2
#
#      alk_phosphate   sgot  albumin  protime  histology class
# 0             85.0   18.0      4.0      NaN      False  live
# 1            135.0   42.0      3.5      NaN      False  live
# 2             96.0   32.0      4.0      NaN      False  live
# 3             46.0   52.0      4.0     80.0      False  live
# 4              NaN  200.0      4.0      NaN      False  live
# ..             ...    ...      ...      ...        ...   ...
# 150            NaN  242.0      3.3     50.0       True   die
# 151          126.0  142.0      4.3      NaN       True  live
# 152           75.0   20.0      4.1      NaN       True  live
# 153           81.0   19.0      4.1     48.0       True  live
# 154          100.0   19.0      3.1     42.0       True   die
#
# [155 rows x 20 columns]

# %% [markdown]
# As an alternative, we can specify only the column on which the dropping operation must be applied. In the following example, only missing rows related to the column liver_big are considered. This can be achieved through the subset parameter, which permits to specify the subset of columns where to apply the dropping operation.
#
# First we will create a copy of df (df1) and then remove missing value

# %%
df1=df.copy()
df1
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0        False           False   False   False   False        1.0
# 1        False           False   False   False   False        0.9
# 2        False           False   False   False   False        0.7
# 3        False           False   False   False   False        0.7
# 4        False           False   False   False   False        1.0
# ..         ...             ...     ...     ...     ...        ...
# 150      False           False    True    True    True        7.6
# 151       True           False   False   False   False        0.9
# 152       True           False    True   False   False        0.8
# 153      False            True    True   False    True        1.5
# 154      False            True    True    True   False        1.2
#
#      alk_phosphate   sgot  albumin  protime  histology class
# 0             85.0   18.0      4.0      NaN      False  live
# 1            135.0   42.0      3.5      NaN      False  live
# 2             96.0   32.0      4.0      NaN      False  live
# 3             46.0   52.0      4.0     80.0      False  live
# 4              NaN  200.0      4.0      NaN      False  live
# ..             ...    ...      ...      ...        ...   ...
# 150            NaN  242.0      3.3     50.0       True   die
# 151          126.0  142.0      4.3      NaN       True  live
# 152           75.0   20.0      4.1      NaN       True  live
# 153           81.0   19.0      4.1     48.0       True  live
# 154          100.0   19.0      3.1     42.0       True   die
#
# [155 rows x 20 columns]

# %%
# drop only the rows in which the column "albumin" has missing values
df1.dropna(subset=['albumin'],axis=0,inplace=True)
df1
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0        False           False   False   False   False        1.0
# 1        False           False   False   False   False        0.9
# 2        False           False   False   False   False        0.7
# 3        False           False   False   False   False        0.7
# 4        False           False   False   False   False        1.0
# ..         ...             ...     ...     ...     ...        ...
# 150      False           False    True    True    True        7.6
# 151       True           False   False   False   False        0.9
# 152       True           False    True   False   False        0.8
# 153      False            True    True   False    True        1.5
# 154      False            True    True    True   False        1.2
#
#      alk_phosphate   sgot  albumin  protime  histology class
# 0             85.0   18.0      4.0      NaN      False  live
# 1            135.0   42.0      3.5      NaN      False  live
# 2             96.0   32.0      4.0      NaN      False  live
# 3             46.0   52.0      4.0     80.0      False  live
# 4              NaN  200.0      4.0      NaN      False  live
# ..             ...    ...      ...      ...        ...   ...
# 150            NaN  242.0      3.3     50.0       True   die
# 151          126.0  142.0      4.3      NaN       True  live
# 152           75.0   20.0      4.1      NaN       True  live
# 153           81.0   19.0      4.1     48.0       True  live
# 154          100.0   19.0      3.1     42.0       True   die
#
# [139 rows x 20 columns]

# %% [markdown]
# Now we can check whether there are still missing values for the column "albumin"

# %%
df1.isna().sum()/len(df1)*100
# Out:
# age                 0.000000
# sex                 0.000000
# steroid             0.719424
# antivirals          0.000000
# fatigue             0.000000
# malaise             0.000000
# anorexia            0.000000
# liver_big           5.035971
# liver_firm          5.755396
# spleen_palpable     2.877698
# spiders             2.877698
# ascites             2.877698
# varices             2.877698
# bilirubin           0.000000
# alk_phosphate      13.669065
# sgot                0.000000
# albumin             0.000000
# protime            37.410072
# histology           0.000000
# class               0.000000
# dtype: float64

# %% [markdown]
# Another alternative involves the dropping of columns where a certain percentage of not-null values is available. This can be achieved through the thresh parameter. In the following example we keep only columns where there are at least the 80% of not null values.

# %%
df1.dropna(thresh=0.8*len(df1),axis=1,inplace=True)
df1
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0        False           False   False   False   False        1.0
# 1        False           False   False   False   False        0.9
# 2        False           False   False   False   False        0.7
# 3        False           False   False   False   False        0.7
# 4        False           False   False   False   False        1.0
# ..         ...             ...     ...     ...     ...        ...
# 150      False           False    True    True    True        7.6
# 151       True           False   False   False   False        0.9
# 152       True           False    True   False   False        0.8
# 153      False            True    True   False    True        1.5
# 154      False            True    True    True   False        1.2
#
#      alk_phosphate   sgot  albumin  histology class
# 0             85.0   18.0      4.0      False  live
# 1            135.0   42.0      3.5      False  live
# 2             96.0   32.0      4.0      False  live
# 3             46.0   52.0      4.0      False  live
# 4              NaN  200.0      4.0      False  live
# ..             ...    ...      ...        ...   ...
# 150            NaN  242.0      3.3       True   die
# 151          126.0  142.0      4.3       True  live
# 152           75.0   20.0      4.1       True  live
# 153           81.0   19.0      4.1       True  live
# 154          100.0   19.0      3.1       True   die
#
# [139 rows x 19 columns]

# %%
len(df1)
# Out:
# 139

# %% [markdown]
# checking the number of live and die instances in "class" column (finding class distribution)

# %%
df1['class'].value_counts()
# Out:
# class
# live    112
# die      27
# Name: count, dtype: int64

# %% [markdown]
# Finding the this data in percentage

# %%
df1['class'].value_counts()/len(df1)*100
# Out:
# class
# live    80.57554
# die     19.42446
# Name: count, dtype: float64

# %% [markdown]
# plotting this data

# %%
pd.value_counts(df1['class']).plot.bar()
# Out:
# <ipython-input-30-9f15172009ab>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df1['class']).plot.bar()
# <Axes: xlabel='class'>

# %% [markdown]
# ICP 1: Replace the missing values in numeric columns of  dataset (hepatitis dataset) with the mean values of the column.

# %%
# Step 1: Firstly, I have created a new dataframe from the main dataframe to implement the request and printed that dataframe.
df_newdataframe=df.copy()
from tabulate import tabulate
print(tabulate(df_newdataframe, headers='keys', tablefmt='pretty')) #styling the table.

# Step 2: Next I find the meanvalue of the column and I have printed the meanvalue.
Meanvalue = df_newdataframe.mean(numeric_only=True)
print(Meanvalue)

# Step 3: In this step, I have replaced the null values with the meanvalue.
df_newdataframe=df_newdataframe.fillna(Meanvalue)

# Step 4: Here, I have printed the dataframe after performing the above operation.
from tabulate import tabulate
print(tabulate(df_newdataframe, headers='keys', tablefmt='pretty')) #styling the table.

# Step 5: Finally, I have verified the null values in the columns.
print(df_newdataframe.isnull().sum())
# Out:
# +-----+-----+--------+---------+------------+---------+---------+----------+-----------+------------+-----------------+---------+---------+---------+-----------+---------------+-------+---------+---------+-----------+-------+
# |     | age |  sex   | steroid | antivirals | fatigue | malaise | anorexia | liver_big | liver_firm | spleen_palpable | spiders | ascites | varices | bilirubin | alk_phosphate | sgot  | albumin | protime | histology | class |
# +-----+-----+--------+---------+------------+---------+---------+----------+-----------+------------+-----------------+---------+---------+---------+-----------+---------------+-------+---------+---------+-----------+-------+
# |  0  | 30  |  male  |  False  |   False    |  False  |  False  |  False   |   False   |   False    |      False      |  False  |  False  |  False  |    1.0    |     85.0      | 18.0  |   4.0   |   nan   |   False   | live  |
# |  1  | 50  | female |  False  |   False    |  True   |  False  |  False   |   False   |   False    |      False      |  False  |  False  |  False  |    0.9    |     135.0     | 42.0  |   3.5   |   nan   |   False   | live  |
# |  2  | 78  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     96.0      | 32.0  |   4.0   |   nan   |   False   | live  |
# |  3  | 31  | female |   nan   |    True    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     46.0      | 52.0  |   4.0   |  80.0   |   False   | live  |
# |  4  | 34  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |      nan      | 200.0 |   4.0   |   nan   |   False   | live  |
# |  5  | 34  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.9    |     95.0      | 28.0  |   4.0   |  75.0   |   False   | live  |
# |  6  | 51  | female |  False  |   False    |  True   |  False  |   True   |   True    |   False    |      True       |  True   |  False  |  False  |    nan    |      nan      |  nan  |   nan   |   nan   |   False   |  die  |
# |  7  | 23  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |      nan      |  nan  |   nan   |   nan   |   False   | live  |
# |  8  | 39  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    0.7    |      nan      | 48.0  |   4.4   |   nan   |   False   | live  |
# |  9  | 30  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |      nan      | 120.0 |   3.9   |   nan   |   False   | live  |
# | 10  | 39  | female |  False  |    True    |  False  |  False  |  False   |   False   |    True    |      False      |  False  |  False  |  False  |    1.3    |     78.0      | 30.0  |   4.4   |  85.0   |   False   | live  |
# | 11  | 32  | female |  True   |    True    |  True   |  False  |  False   |   True    |    True    |      False      |  True   |  False  |  False  |    1.0    |     59.0      | 249.0 |   3.7   |  54.0   |   False   | live  |
# | 12  | 41  | female |  True   |    True    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    0.9    |     81.0      | 60.0  |   3.9   |  52.0   |   False   | live  |
# | 13  | 30  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    2.2    |     57.0      | 144.0 |   4.9   |  78.0   |   False   | live  |
# | 14  | 47  | female |  False  |    True    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    nan    |      nan      | 60.0  |   nan   |   nan   |   False   | live  |
# | 15  | 38  | female |  False  |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  False  |  True   |  False  |    2.0    |     72.0      | 89.0  |   2.9   |  46.0   |   False   | live  |
# | 16  | 66  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.2    |     102.0     | 53.0  |   4.3   |   nan   |   False   | live  |
# | 17  | 40  | female |  False  |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    0.6    |     62.0      | 166.0 |   4.0   |  63.0   |   False   | live  |
# | 18  | 38  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     53.0      | 42.0  |   4.1   |  85.0   |   True    | live  |
# | 19  | 38  | female |  False  |    True    |  False  |  False  |  False   |   False   |    True    |      False      |  False  |  False  |  False  |    0.7    |     70.0      | 28.0  |   4.2   |  62.0   |   False   | live  |
# | 20  | 22  |  male  |  True   |    True    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.9    |     48.0      | 20.0  |   4.2   |  64.0   |   False   | live  |
# | 21  | 27  | female |  True   |   False    |  True   |  True   |   True   |   False   |    True    |      True       |  True   |  False  |  False  |    1.2    |     133.0     | 98.0  |   4.1   |  39.0   |   False   | live  |
# | 22  | 31  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |     85.0      | 20.0  |   4.0   |  100.0  |   False   | live  |
# | 23  | 42  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.9    |     60.0      | 63.0  |   4.7   |  47.0   |   False   | live  |
# | 24  | 25  |  male  |  False  |    True    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.4    |     45.0      | 18.0  |   4.3   |  70.0   |   False   | live  |
# | 25  | 27  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.8    |     95.0      | 46.0  |   3.8   |  100.0  |   False   | live  |
# | 26  | 49  | female |  False  |    True    |  True   |  True   |   True   |   True    |    True    |      False      |  True   |  False  |  False  |    0.6    |     85.0      | 48.0  |   3.7   |   nan   |   False   | live  |
# | 27  | 58  |  male  |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  True   |  False  |  False  |    1.4    |     175.0     | 55.0  |   2.7   |  36.0   |   False   | live  |
# | 28  | 61  | female |  False  |   False    |  True   |  False  |  False   |   False   |    True    |      False      |  False  |  False  |  False  |    1.3    |     78.0      | 25.0  |   3.8   |  100.0  |   False   | live  |
# | 29  | 51  | female |  False  |    True    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |     78.0      | 58.0  |   4.6   |  52.0   |   False   | live  |
# | 30  | 39  | female |  False  |    True    |  True   |  True   |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    2.3    |     280.0     | 98.0  |   3.8   |  40.0   |   False   |  die  |
# | 31  | 62  | female |  False  |   False    |  True   |  True   |  False   |    nan    |    nan     |      False      |  False  |  False  |  False  |    1.0    |      nan      | 60.0  |   nan   |   nan   |   False   |  die  |
# | 32  | 41  |  male  |  True   |    True    |  True   |  True   |   True   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     81.0      | 53.0  |   5.0   |  74.0   |   False   | live  |
# | 33  | 26  |  male  |  False  |   False    |  False  |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    0.5    |     135.0     | 29.0  |   3.8   |  60.0   |   False   | live  |
# | 34  | 35  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.9    |     58.0      | 92.0  |   4.3   |  73.0   |   False   | live  |
# | 35  | 37  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  True   |  False  |  False  |    0.6    |     67.0      | 28.0  |   4.2   |   nan   |   False   |  die  |
# | 36  | 23  | female |  True   |   False    |  True   |  True   |   True   |   True    |   False    |      True       |  False  |  False  |  False  |    1.3    |     194.0     | 150.0 |   4.1   |  90.0   |   False   | live  |
# | 37  | 20  |  male  |  False  |   False    |  True   |  True   |   True   |   False   |    True    |      True       |  True   |  False  |  False  |    2.3    |     150.0     | 68.0  |   3.9   |   nan   |   False   | live  |
# | 38  | 42  | female |  False  |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |     85.0      | 14.0  |   4.0   |  100.0  |   False   | live  |
# | 39  | 65  | female |  True   |   False    |  True   |  True   |  False   |   True    |    True    |      True       |  True   |  True   |  False  |    0.3    |     180.0     | 53.0  |   2.9   |  74.0   |   True    | live  |
# | 40  | 52  | female |  False  |    True    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     75.0      | 55.0  |   4.0   |  21.0   |   False   | live  |
# | 41  | 23  | female |  True   |   False    |  False  |  False  |  False   |    nan    |    nan     |       nan       |   nan   |   nan   |   nan   |    4.6    |     56.0      | 16.0  |   4.6   |   nan   |   False   | live  |
# | 42  | 33  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |     46.0      | 90.0  |   4.4   |  60.0   |   False   | live  |
# | 43  | 56  | female |  False  |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     71.0      | 18.0  |   4.4   |  100.0  |   False   | live  |
# | 44  | 34  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    nan    |      nan      | 86.0  |   nan   |   nan   |   False   | live  |
# | 45  | 28  | female |  True   |   False    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     74.0      | 110.0 |   4.4   |   nan   |   False   | live  |
# | 46  | 37  | female |  False  |   False    |  False  |  False  |  False   |   True    |    True    |      False      |  True   |  False  |  False  |    0.6    |     80.0      | 80.0  |   3.8   |   nan   |   False   | live  |
# | 47  | 28  |  male  |  True   |   False    |  True   |  True   |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    1.8    |     191.0     | 420.0 |   3.3   |  46.0   |   False   | live  |
# | 48  | 36  | female |  False  |   False    |  False  |  False  |  False   |   True    |   False    |      True       |  False  |  False  |  False  |    0.8    |     85.0      | 44.0  |   4.2   |  85.0   |   False   | live  |
# | 49  | 38  | female |  True   |    True    |  True   |  True   |   True   |   True    |   False    |      False      |  True   |  False  |  False  |    0.7    |     125.0     | 65.0  |   4.2   |  77.0   |   False   | live  |
# | 50  | 39  | female |  False  |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.9    |     85.0      | 60.0  |   4.0   |   nan   |   False   | live  |
# | 51  | 39  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |     85.0      | 20.0  |   4.0   |   nan   |   False   | live  |
# | 52  | 44  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.6    |     110.0     | 145.0 |   4.4   |  70.0   |   False   | live  |
# | 53  | 40  | female |  True   |    True    |  True   |  False  |  False   |   True    |    True    |      True       |  False  |  False  |  False  |    1.2    |     85.0      | 31.0  |   4.0   |  100.0  |   False   | live  |
# | 54  | 30  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     50.0      | 78.0  |   4.2   |  74.0   |   False   | live  |
# | 55  | 37  | female |  False  |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  False  |  False  |  False  |    0.8    |     92.0      | 59.0  |   nan   |   nan   |   False   | live  |
# | 56  | 34  | female |  False  |   False    |   nan   |   nan   |   nan    |    nan    |    nan     |       nan       |   nan   |   nan   |   nan   |    nan    |      nan      |  nan  |   nan   |   nan   |   False   | live  |
# | 57  | 30  | female |  True   |    True    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     52.0      | 38.0  |   3.9   |  52.0   |   False   | live  |
# | 58  | 64  | female |  True   |    True    |  True   |  True   |  False   |   False   |    True    |      False      |  False  |  False  |  False  |    1.0    |     80.0      | 38.0  |   4.3   |  74.0   |   False   | live  |
# | 59  | 45  |  male  |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      True       |  False  |  False  |  False  |    1.0    |     85.0      | 75.0  |   nan   |   nan   |   False   | live  |
# | 60  | 37  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     26.0      | 58.0  |   4.5   |  100.0  |   False   | live  |
# | 61  | 32  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     102.0     | 64.0  |   4.0   |  90.0   |   False   | live  |
# | 62  | 32  | female |  True   |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  True   |  False  |  True   |    3.5    |     215.0     | 54.0  |   3.4   |  29.0   |   False   | live  |
# | 63  | 36  | female |  False  |   False    |  False  |  False  |  False   |   False   |    True    |      True       |  False  |  False  |  False  |    0.7    |     164.0     | 44.0  |   3.1   |  41.0   |   False   | live  |
# | 64  | 49  | female |  True   |   False    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.8    |     103.0     | 43.0  |   3.5   |  66.0   |   False   | live  |
# | 65  | 27  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.8    |      nan      | 38.0  |   4.2   |   nan   |   False   | live  |
# | 66  | 56  | female |  False  |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     62.0      | 33.0  |   3.0   |   nan   |   False   | live  |
# | 67  | 57  | female |  True   |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  True   |  True   |  False  |    4.1    |      nan      | 48.0  |   2.6   |  73.0   |   False   |  die  |
# | 68  | 39  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |     34.0      | 15.0  |   4.0   |  54.0   |   False   | live  |
# | 69  | 44  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.6    |     68.0      | 68.0  |   3.7   |   nan   |   False   | live  |
# | 70  | 24  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.8    |     82.0      | 39.0  |   4.3   |   nan   |   False   | live  |
# | 71  | 34  | female |  False  |   False    |  True   |  True   |  False   |   False   |    True    |      False      |  True   |  False  |  False  |    2.8    |     127.0     | 182.0 |   nan   |   nan   |   False   |  die  |
# | 72  | 51  | female |  True   |   False    |  True   |  True   |   True   |    nan    |    nan     |       nan       |   nan   |   nan   |   nan   |    0.9    |     76.0      | 271.0 |   4.4   |   nan   |   False   | live  |
# | 73  | 36  | female |  False  |   False    |  True   |  True   |   True   |   True    |    True    |      False      |  False  |  False  |  False  |    1.0    |      nan      | 45.0  |   4.0   |  57.0   |   False   | live  |
# | 74  | 50  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.5    |     100.0     | 100.0 |   5.3   |   nan   |   False   | live  |
# | 75  | 32  | female |  False  |    True    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |     55.0      | 45.0  |   4.1   |  56.0   |   False   | live  |
# | 76  | 58  | female |  True   |   False    |  True   |  False  |  False   |   False   |    True    |      True       |  True   |  False  |  False  |    2.0    |     167.0     | 242.0 |   3.3   |   nan   |   False   |  die  |
# | 77  | 34  |  male  |  False  |    True    |  False  |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    0.6    |     30.0      | 24.0  |   4.0   |  76.0   |   False   | live  |
# | 78  | 34  | female |  False  |   False    |  True   |  False  |  False   |   False   |    True    |      False      |  True   |  False  |  False  |    1.0    |     72.0      | 46.0  |   4.4   |  57.0   |   False   | live  |
# | 79  | 28  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     85.0      | 31.0  |   4.9   |   nan   |   False   | live  |
# | 80  | 23  | female |  True   |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  False  |  False  |  False  |    0.8    |      nan      | 14.0  |   4.8   |   nan   |   False   | live  |
# | 81  | 36  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     62.0      | 224.0 |   4.2   |  100.0  |   False   | live  |
# | 82  | 30  | female |  False  |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |     100.0     | 31.0  |   4.0   |  100.0  |   False   | live  |
# | 83  | 67  |  male  |  False  |   False    |  True   |  True   |  False   |   True    |   False    |       nan       |   nan   |   nan   |   nan   |    1.5    |     179.0     | 69.0  |   2.9   |   nan   |   False   | live  |
# | 84  | 62  |  male  |  True   |   False    |  True   |  True   |  False   |   True    |    True    |      False      |  True   |  False  |  False  |    1.3    |     141.0     | 156.0 |   3.9   |  58.0   |   False   | live  |
# | 85  | 28  | female |  False  |   False    |  True   |  True   |   True   |   True    |    True    |      False      |  False  |  False  |  False  |    1.6    |     44.0      | 123.0 |   4.0   |  46.0   |   False   | live  |
# | 86  | 44  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      True       |  False  |  False  |  True   |    0.9    |     135.0     | 55.0  |   nan   |  41.0   |   True    |  die  |
# | 87  | 30  | female |  True   |   False    |  True   |  True   |   True   |   True    |    True    |      False      |  True   |  True   |  True   |    2.5    |     165.0     | 64.0  |   2.8   |   nan   |   True    |  die  |
# | 88  | 38  | female |  False  |   False    |  True   |  True   |   True   |   True    |    True    |      False      |  True   |  True   |  True   |    1.2    |     118.0     | 16.0  |   2.8   |   nan   |   True    |  die  |
# | 89  | 38  | female |  False  |   False    |  True   |  True   |   True   |   False   |    True    |      False      |  False  |  False  |  False  |    0.6    |     76.0      | 18.0  |   4.4   |  84.0   |   True    | live  |
# | 90  | 50  |  male  |  False  |   False    |  True   |  False  |  False   |   False   |    True    |      True       |  True   |  False  |  False  |    0.9    |     230.0     | 117.0 |   3.4   |  41.0   |   True    | live  |
# | 91  | 42  | female |  False  |   False    |  True   |  True   |   True   |   True    |   False    |      True       |  True   |  False  |  True   |    4.6    |      nan      | 55.0  |   3.3   |   nan   |   True    |  die  |
# | 92  | 33  | female |  True   |   False    |  False  |  False  |  False   |    nan    |    nan     |      False      |  False  |  False  |  False  |    1.0    |      nan      | 60.0  |   4.0   |   nan   |   True    | live  |
# | 93  | 52  | female |  False  |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.5    |      nan      | 69.0  |   2.9   |   nan   |   True    | live  |
# | 94  | 59  | female |  False  |   False    |  True   |  True   |  False   |   True    |    True    |      True       |  True   |  False  |  False  |    1.5    |     107.0     | 157.0 |   3.6   |  38.0   |   True    |  die  |
# | 95  | 40  | female |  False  |    True    |  True   |  True   |   True   |   False   |    True    |      False      |  False  |  False  |  False  |    0.6    |     40.0      | 69.0  |   4.2   |  67.0   |   True    | live  |
# | 96  | 30  | female |  False  |   False    |  True   |  True   |  False   |   True    |    True    |      False      |  True   |  False  |  False  |    0.8    |     147.0     | 128.0 |   3.9   |  100.0  |   True    | live  |
# | 97  | 44  | female |  False  |   False    |  True   |  True   |  False   |   False   |    True    |      False      |  True   |  False  |  False  |    3.0    |     114.0     | 65.0  |   3.5   |   nan   |   True    | live  |
# | 98  | 47  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  True   |  False  |  True   |    2.0    |     84.0      | 23.0  |   4.2   |  66.0   |   True    |  die  |
# | 99  | 60  | female |  False  |   False    |  True   |  False  |  False   |   False   |    True    |      True       |  True   |  False  |  False  |    nan    |      nan      | 40.0  |   nan   |   nan   |   True    | live  |
# | 100 | 48  | female |  False  |   False    |  True   |  True   |  False   |   True    |    True    |      False      |  True   |  True   |  True   |    4.8    |     123.0     | 157.0 |   2.7   |  31.0   |   True    |  die  |
# | 101 | 22  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.7    |      nan      | 24.0  |   nan   |   nan   |   True    | live  |
# | 102 | 27  | female |  False  |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    2.4    |     168.0     | 227.0 |   3.0   |  66.0   |   True    | live  |
# | 103 | 51  | female |  False  |   False    |  True   |  True   |   True   |   True    |    True    |      True       |  True   |  False  |  True   |    4.6    |     215.0     | 269.0 |   3.9   |  51.0   |   True    | live  |
# | 104 | 47  | female |  True   |   False    |  True   |  True   |  False   |   True    |    True    |      False      |  False  |  True   |  True   |    1.7    |     86.0      | 20.0  |   2.1   |  46.0   |   True    |  die  |
# | 105 | 25  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.6    |      nan      | 34.0  |   6.4   |   nan   |   True    | live  |
# | 106 | 35  | female |  False  |   False    |  True   |  False  |  False   |    nan    |    nan     |      True       |  True   |  True   |  False  |    1.5    |     138.0     | 58.0  |   2.6   |   nan   |   True    |  die  |
# | 107 | 45  | female |  False  |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  False  |  False  |  False  |    2.3    |      nan      | 648.0 |   nan   |   nan   |   True    | live  |
# | 108 | 54  | female |  False  |    True    |  False  |  False  |  False   |   False   |    True    |      False      |  False  |  False  |  False  |    1.0    |     155.0     | 225.0 |   3.6   |  67.0   |   True    | live  |
# | 109 | 33  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  True   |  False  |    0.7    |     63.0      | 80.0  |   3.0   |  31.0   |   True    |  die  |
# | 110 |  7  | female |  True   |   False    |  False  |  False  |  False   |   True    |    True    |      True       |  False  |  False  |  False  |    0.7    |     256.0     | 25.0  |   4.2   |   nan   |   True    | live  |
# | 111 | 42  | female |  False  |    True    |  True   |  True   |  False   |   True    |   False    |      False      |  True   |  False  |  False  |    0.5    |     62.0      | 68.0  |   3.8   |  29.0   |   True    |  die  |
# | 112 | 52  | female |  False  |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |     85.0      | 30.0  |   4.0   |   nan   |   True    | live  |
# | 113 | 45  | female |  False  |   False    |  True   |  False  |  False   |   True    |    True    |      True       |  False  |  False  |  False  |    1.2    |     81.0      | 65.0  |   3.0   |   nan   |   False   | live  |
# | 114 | 36  | female |  False  |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.1    |     141.0     | 75.0  |   3.3   |   nan   |   True    | live  |
# | 115 | 69  |  male  |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    3.2    |     119.0     | 136.0 |   nan   |   nan   |   True    | live  |
# | 116 | 24  | female |  False  |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |      nan      | 34.0  |   4.1   |   nan   |   True    | live  |
# | 117 | 50  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |     139.0     | 81.0  |   3.9   |  62.0   |   True    | live  |
# | 118 | 61  | female |  False  |   False    |  True   |  True   |  False   |    nan    |    nan     |      False      |  True   |  False  |  False  |    nan    |      nan      |  nan  |   nan   |   nan   |   True    |  die  |
# | 119 | 54  | female |  True   |   False    |  True   |  False  |  False   |   False   |    True    |      False      |  False  |  False  |  False  |    3.2    |     85.0      | 28.0  |   3.8   |   nan   |   True    | live  |
# | 120 | 56  | female |  False  |   False    |  True   |  True   |   True   |   False   |    True    |      False      |  True   |  False  |  False  |    2.9    |     90.0      | 153.0 |   4.0   |   nan   |   True    |  die  |
# | 121 | 20  | female |  False  |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  True   |  True   |  False  |    1.0    |     160.0     | 118.0 |   2.9   |  23.0   |   True    | live  |
# | 122 | 42  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      True       |  False  |  False  |  False  |    1.5    |     85.0      | 40.0  |   nan   |   nan   |   True    | live  |
# | 123 | 37  | female |  False  |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  True   |  False  |  False  |    0.9    |      nan      | 231.0 |   4.3   |   nan   |   True    | live  |
# | 124 | 50  | female |  True   |   False    |  False  |  False  |  False   |   True    |    True    |      True       |  True   |  False  |  False  |    1.0    |     85.0      | 75.0  |   4.0   |  72.0   |   True    | live  |
# | 125 | 34  |  male  |  True   |   False    |  True   |  True   |   True   |   False   |    True    |      False      |  True   |  False  |  False  |    0.7    |     70.0      | 24.0  |   4.1   |  100.0  |   True    | live  |
# | 126 | 28  | female |  True   |   False    |  True   |  True   |   True   |    nan    |    nan     |      False      |  True   |  True   |  False  |    1.0    |      nan      | 20.0  |   4.0   |   nan   |   True    | live  |
# | 127 | 50  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      True       |  False  |  True   |  True   |    2.8    |     155.0     | 75.0  |   2.4   |  32.0   |   True    |  die  |
# | 128 | 54  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  True   |  False  |    1.2    |     85.0      | 92.0  |   3.1   |  66.0   |   True    | live  |
# | 129 | 57  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      False      |  True   |  True   |  False  |    4.6    |     82.0      | 55.0  |   3.3   |  30.0   |   True    |  die  |
# | 130 | 54  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.0    |     85.0      | 30.0  |   4.5   |   0.0   |   True    | live  |
# | 131 | 31  | female |  False  |   False    |  True   |  True   |   True   |   True    |   False    |      True       |  False  |  False  |  False  |    8.0    |      nan      | 101.0 |   2.2   |   nan   |   True    |  die  |
# | 132 | 48  | female |  True   |   False    |  True   |  True   |   True   |   True    |    True    |      False      |  True   |  False  |  False  |    2.0    |     158.0     | 278.0 |   3.8   |   nan   |   True    | live  |
# | 133 | 72  | female |  True   |    True    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    1.0    |     115.0     | 52.0  |   3.4   |  50.0   |   True    | live  |
# | 134 | 38  | female |  False  |   False    |  False  |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    0.4    |     243.0     | 49.0  |   3.8   |  90.0   |   True    |  die  |
# | 135 | 25  | female |  True   |   False    |  True   |  False  |  False   |   False   |    True    |      True       |  True   |  True   |  True   |    1.3    |     181.0     | 181.0 |   4.5   |  57.0   |   True    | live  |
# | 136 | 51  | female |  True   |   False    |  False  |  False  |  False   |   False   |    True    |      False      |  True   |  False  |  False  |    0.8    |      nan      | 33.0  |   4.5   |   nan   |   True    | live  |
# | 137 | 38  | female |  True   |   False    |  False  |  False  |  False   |   True    |    True    |      False      |  True   |  False  |  True   |    1.6    |     130.0     | 140.0 |   3.5   |  56.0   |   True    | live  |
# | 138 | 47  | female |  True   |   False    |  True   |  True   |  False   |   True    |    True    |      False      |  True   |  True   |  True   |    1.0    |     166.0     | 30.0  |   2.6   |  31.0   |   True    |  die  |
# | 139 | 45  | female |  True   |    True    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.3    |     85.0      | 44.0  |   4.2   |  85.0   |   True    | live  |
# | 140 | 36  | female |  False  |   False    |  True   |  True   |   True   |   False   |    True    |      False      |  True   |  False  |  True   |    1.7    |     295.0     | 60.0  |   2.7   |   nan   |   True    | live  |
# | 141 | 54  | female |  False  |   False    |  True   |  True   |  False   |    nan    |    nan     |      True       |  False  |  True   |  False  |    3.9    |     120.0     | 28.0  |   3.5   |  43.0   |   True    |  die  |
# | 142 | 51  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      True       |  True   |  False  |  True   |    1.0    |      nan      | 20.0  |   3.0   |  63.0   |   True    | live  |
# | 143 | 49  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      True       |  True   |  False  |  False  |    1.4    |     85.0      | 70.0  |   3.5   |  35.0   |   True    |  die  |
# | 144 | 45  | female |  True   |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  True   |  True   |  False  |    1.9    |      nan      | 114.0 |   2.4   |   nan   |   True    |  die  |
# | 145 | 31  | female |  False  |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    1.2    |     75.0      | 173.0 |   4.2   |  54.0   |   True    | live  |
# | 146 | 41  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      True       |  True   |  False  |  True   |    4.2    |     65.0      | 120.0 |   3.4   |   nan   |   True    |  die  |
# | 147 | 70  | female |  False  |   False    |  True   |  True   |   True   |    nan    |    nan     |       nan       |   nan   |   nan   |   nan   |    1.7    |     109.0     | 528.0 |   2.8   |  35.0   |   True    |  die  |
# | 148 | 20  | female |  False  |   False    |  False  |  False  |  False   |   True    |    nan     |      False      |  False  |  False  |  False  |    0.9    |     89.0      | 152.0 |   4.0   |   nan   |   True    | live  |
# | 149 | 36  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |    0.6    |     120.0     | 30.0  |   4.0   |   nan   |   True    | live  |
# | 150 | 46  | female |  True   |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  True   |  True   |  True   |    7.6    |      nan      | 242.0 |   3.3   |  50.0   |   True    |  die  |
# | 151 | 44  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |    0.9    |     126.0     | 142.0 |   4.3   |   nan   |   True    | live  |
# | 152 | 61  | female |  False  |   False    |  True   |  True   |  False   |   False   |    True    |      False      |  True   |  False  |  False  |    0.8    |     75.0      | 20.0  |   4.1   |   nan   |   True    | live  |
# | 153 | 53  |  male  |  False  |   False    |  True   |  False  |  False   |   True    |   False    |      True       |  True   |  False  |  True   |    1.5    |     81.0      | 19.0  |   4.1   |  48.0   |   True    | live  |
# | 154 | 43  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      True       |  True   |  True   |  False  |    1.2    |     100.0     | 19.0  |   3.1   |  42.0   |   True    |  die  |
# +-----+-----+--------+---------+------------+---------+---------+----------+-----------+------------+-----------------+---------+---------+---------+-----------+---------------+-------+---------+---------+-----------+-------+
# age               41.200000
# antivirals         0.154839
# bilirubin          1.427517
# alk_phosphate    105.325397
# sgot              85.894040
# albumin            3.817266
# protime           61.852273
# histology          0.451613
# dtype: float64
# +-----+-----+--------+---------+------------+---------+---------+----------+-----------+------------+-----------------+---------+---------+---------+------------------+--------------------+-------------------+--------------------+-------------------+-----------+-------+
# |     | age |  sex   | steroid | antivirals | fatigue | malaise | anorexia | liver_big | liver_firm | spleen_palpable | spiders | ascites | varices |    bilirubin     |   alk_phosphate    |       sgot        |      albumin       |      protime      | histology | class |
# +-----+-----+--------+---------+------------+---------+---------+----------+-----------+------------+-----------------+---------+---------+---------+------------------+--------------------+-------------------+--------------------+-------------------+-----------+-------+
# |  0  | 30  |  male  |  False  |   False    |  False  |  False  |  False   |   False   |   False    |      False      |  False  |  False  |  False  |       1.0        |        85.0        |       18.0        |        4.0         | 61.85227272727273 |   False   | live  |
# |  1  | 50  | female |  False  |   False    |  True   |  False  |  False   |   False   |   False    |      False      |  False  |  False  |  False  |       0.9        |       135.0        |       42.0        |        3.5         | 61.85227272727273 |   False   | live  |
# |  2  | 78  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.7        |        96.0        |       32.0        |        4.0         | 61.85227272727273 |   False   | live  |
# |  3  | 31  | female |   nan   |    True    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.7        |        46.0        |       52.0        |        4.0         |       80.0        |   False   | live  |
# |  4  | 34  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.0        | 105.32539682539682 |       200.0       |        4.0         | 61.85227272727273 |   False   | live  |
# |  5  | 34  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.9        |        95.0        |       28.0        |        4.0         |       75.0        |   False   | live  |
# |  6  | 51  | female |  False  |   False    |  True   |  False  |   True   |   True    |   False    |      True       |  True   |  False  |  False  | 1.42751677852349 | 105.32539682539682 | 85.89403973509934 | 3.8172661870503606 | 61.85227272727273 |   False   |  die  |
# |  7  | 23  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.0        | 105.32539682539682 | 85.89403973509934 | 3.8172661870503606 | 61.85227272727273 |   False   | live  |
# |  8  | 39  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |       0.7        | 105.32539682539682 |       48.0        |        4.4         | 61.85227272727273 |   False   | live  |
# |  9  | 30  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.0        | 105.32539682539682 |       120.0       |        3.9         | 61.85227272727273 |   False   | live  |
# | 10  | 39  | female |  False  |    True    |  False  |  False  |  False   |   False   |    True    |      False      |  False  |  False  |  False  |       1.3        |        78.0        |       30.0        |        4.4         |       85.0        |   False   | live  |
# | 11  | 32  | female |  True   |    True    |  True   |  False  |  False   |   True    |    True    |      False      |  True   |  False  |  False  |       1.0        |        59.0        |       249.0       |        3.7         |       54.0        |   False   | live  |
# | 12  | 41  | female |  True   |    True    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |       0.9        |        81.0        |       60.0        |        3.9         |       52.0        |   False   | live  |
# | 13  | 30  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |       2.2        |        57.0        |       144.0       |        4.9         |       78.0        |   False   | live  |
# | 14  | 47  | female |  False  |    True    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  | 1.42751677852349 | 105.32539682539682 |       60.0        | 3.8172661870503606 | 61.85227272727273 |   False   | live  |
# | 15  | 38  | female |  False  |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  False  |  True   |  False  |       2.0        |        72.0        |       89.0        |        2.9         |       46.0        |   False   | live  |
# | 16  | 66  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.2        |       102.0        |       53.0        |        4.3         | 61.85227272727273 |   False   | live  |
# | 17  | 40  | female |  False  |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |       0.6        |        62.0        |       166.0       |        4.0         |       63.0        |   False   | live  |
# | 18  | 38  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.7        |        53.0        |       42.0        |        4.1         |       85.0        |   True    | live  |
# | 19  | 38  | female |  False  |    True    |  False  |  False  |  False   |   False   |    True    |      False      |  False  |  False  |  False  |       0.7        |        70.0        |       28.0        |        4.2         |       62.0        |   False   | live  |
# | 20  | 22  |  male  |  True   |    True    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.9        |        48.0        |       20.0        |        4.2         |       64.0        |   False   | live  |
# | 21  | 27  | female |  True   |   False    |  True   |  True   |   True   |   False   |    True    |      True       |  True   |  False  |  False  |       1.2        |       133.0        |       98.0        |        4.1         |       39.0        |   False   | live  |
# | 22  | 31  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.0        |        85.0        |       20.0        |        4.0         |       100.0       |   False   | live  |
# | 23  | 42  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.9        |        60.0        |       63.0        |        4.7         |       47.0        |   False   | live  |
# | 24  | 25  |  male  |  False  |    True    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.4        |        45.0        |       18.0        |        4.3         |       70.0        |   False   | live  |
# | 25  | 27  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.8        |        95.0        |       46.0        |        3.8         |       100.0       |   False   | live  |
# | 26  | 49  | female |  False  |    True    |  True   |  True   |   True   |   True    |    True    |      False      |  True   |  False  |  False  |       0.6        |        85.0        |       48.0        |        3.7         | 61.85227272727273 |   False   | live  |
# | 27  | 58  |  male  |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  True   |  False  |  False  |       1.4        |       175.0        |       55.0        |        2.7         |       36.0        |   False   | live  |
# | 28  | 61  | female |  False  |   False    |  True   |  False  |  False   |   False   |    True    |      False      |  False  |  False  |  False  |       1.3        |        78.0        |       25.0        |        3.8         |       100.0       |   False   | live  |
# | 29  | 51  | female |  False  |    True    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.0        |        78.0        |       58.0        |        4.6         |       52.0        |   False   | live  |
# | 30  | 39  | female |  False  |    True    |  True   |  True   |  False   |   True    |    True    |      False      |  False  |  False  |  False  |       2.3        |       280.0        |       98.0        |        3.8         |       40.0        |   False   |  die  |
# | 31  | 62  | female |  False  |   False    |  True   |  True   |  False   |    nan    |    nan     |      False      |  False  |  False  |  False  |       1.0        | 105.32539682539682 |       60.0        | 3.8172661870503606 | 61.85227272727273 |   False   |  die  |
# | 32  | 41  |  male  |  True   |    True    |  True   |  True   |   True   |   True    |   False    |      False      |  False  |  False  |  False  |       0.7        |        81.0        |       53.0        |        5.0         |       74.0        |   False   | live  |
# | 33  | 26  |  male  |  False  |   False    |  False  |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |       0.5        |       135.0        |       29.0        |        3.8         |       60.0        |   False   | live  |
# | 34  | 35  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.9        |        58.0        |       92.0        |        4.3         |       73.0        |   False   | live  |
# | 35  | 37  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  True   |  False  |  False  |       0.6        |        67.0        |       28.0        |        4.2         | 61.85227272727273 |   False   |  die  |
# | 36  | 23  | female |  True   |   False    |  True   |  True   |   True   |   True    |   False    |      True       |  False  |  False  |  False  |       1.3        |       194.0        |       150.0       |        4.1         |       90.0        |   False   | live  |
# | 37  | 20  |  male  |  False  |   False    |  True   |  True   |   True   |   False   |    True    |      True       |  True   |  False  |  False  |       2.3        |       150.0        |       68.0        |        3.9         | 61.85227272727273 |   False   | live  |
# | 38  | 42  | female |  False  |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.0        |        85.0        |       14.0        |        4.0         |       100.0       |   False   | live  |
# | 39  | 65  | female |  True   |   False    |  True   |  True   |  False   |   True    |    True    |      True       |  True   |  True   |  False  |       0.3        |       180.0        |       53.0        |        2.9         |       74.0        |   True    | live  |
# ...
# | 99  | 60  | female |  False  |   False    |  True   |  False  |  False   |   False   |    True    |      True       |  True   |  False  |  False  | 1.42751677852349 | 105.32539682539682 |       40.0        | 3.8172661870503606 | 61.85227272727273 |   True    | live  |
# | 100 | 48  | female |  False  |   False    |  True   |  True   |  False   |   True    |    True    |      False      |  True   |  True   |  True   |       4.8        |       123.0        |       157.0       |        2.7         |       31.0        |   True    |  die  |
# | 101 | 22  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.7        | 105.32539682539682 |       24.0        | 3.8172661870503606 | 61.85227272727273 |   True    | live  |
# | 102 | 27  | female |  False  |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |       2.4        |       168.0        |       227.0       |        3.0         |       66.0        |   True    | live  |
# | 103 | 51  | female |  False  |   False    |  True   |  True   |   True   |   True    |    True    |      True       |  True   |  False  |  True   |       4.6        |       215.0        |       269.0       |        3.9         |       51.0        |   True    | live  |
# | 104 | 47  | female |  True   |   False    |  True   |  True   |  False   |   True    |    True    |      False      |  False  |  True   |  True   |       1.7        |        86.0        |       20.0        |        2.1         |       46.0        |   True    |  die  |
# | 105 | 25  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.6        | 105.32539682539682 |       34.0        |        6.4         | 61.85227272727273 |   True    | live  |
# | 106 | 35  | female |  False  |   False    |  True   |  False  |  False   |    nan    |    nan     |      True       |  True   |  True   |  False  |       1.5        |       138.0        |       58.0        |        2.6         | 61.85227272727273 |   True    |  die  |
# | 107 | 45  | female |  False  |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  False  |  False  |  False  |       2.3        | 105.32539682539682 |       648.0       | 3.8172661870503606 | 61.85227272727273 |   True    | live  |
# | 108 | 54  | female |  False  |    True    |  False  |  False  |  False   |   False   |    True    |      False      |  False  |  False  |  False  |       1.0        |       155.0        |       225.0       |        3.6         |       67.0        |   True    | live  |
# | 109 | 33  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  True   |  False  |       0.7        |        63.0        |       80.0        |        3.0         |       31.0        |   True    |  die  |
# | 110 |  7  | female |  True   |   False    |  False  |  False  |  False   |   True    |    True    |      True       |  False  |  False  |  False  |       0.7        |       256.0        |       25.0        |        4.2         | 61.85227272727273 |   True    | live  |
# | 111 | 42  | female |  False  |    True    |  True   |  True   |  False   |   True    |   False    |      False      |  True   |  False  |  False  |       0.5        |        62.0        |       68.0        |        3.8         |       29.0        |   True    |  die  |
# | 112 | 52  | female |  False  |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.0        |        85.0        |       30.0        |        4.0         | 61.85227272727273 |   True    | live  |
# | 113 | 45  | female |  False  |   False    |  True   |  False  |  False   |   True    |    True    |      True       |  False  |  False  |  False  |       1.2        |        81.0        |       65.0        |        3.0         | 61.85227272727273 |   False   | live  |
# | 114 | 36  | female |  False  |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.1        |       141.0        |       75.0        |        3.3         | 61.85227272727273 |   True    | live  |
# | 115 | 69  |  male  |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       3.2        |       119.0        |       136.0       | 3.8172661870503606 | 61.85227272727273 |   True    | live  |
# | 116 | 24  | female |  False  |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.0        | 105.32539682539682 |       34.0        |        4.1         | 61.85227272727273 |   True    | live  |
# | 117 | 50  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.0        |       139.0        |       81.0        |        3.9         |       62.0        |   True    | live  |
# | 118 | 61  | female |  False  |   False    |  True   |  True   |  False   |    nan    |    nan     |      False      |  True   |  False  |  False  | 1.42751677852349 | 105.32539682539682 | 85.89403973509934 | 3.8172661870503606 | 61.85227272727273 |   True    |  die  |
# | 119 | 54  | female |  True   |   False    |  True   |  False  |  False   |   False   |    True    |      False      |  False  |  False  |  False  |       3.2        |        85.0        |       28.0        |        3.8         | 61.85227272727273 |   True    | live  |
# | 120 | 56  | female |  False  |   False    |  True   |  True   |   True   |   False   |    True    |      False      |  True   |  False  |  False  |       2.9        |        90.0        |       153.0       |        4.0         | 61.85227272727273 |   True    |  die  |
# | 121 | 20  | female |  False  |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  True   |  True   |  False  |       1.0        |       160.0        |       118.0       |        2.9         |       23.0        |   True    | live  |
# | 122 | 42  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      True       |  False  |  False  |  False  |       1.5        |        85.0        |       40.0        | 3.8172661870503606 | 61.85227272727273 |   True    | live  |
# | 123 | 37  | female |  False  |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  True   |  False  |  False  |       0.9        | 105.32539682539682 |       231.0       |        4.3         | 61.85227272727273 |   True    | live  |
# | 124 | 50  | female |  True   |   False    |  False  |  False  |  False   |   True    |    True    |      True       |  True   |  False  |  False  |       1.0        |        85.0        |       75.0        |        4.0         |       72.0        |   True    | live  |
# | 125 | 34  |  male  |  True   |   False    |  True   |  True   |   True   |   False   |    True    |      False      |  True   |  False  |  False  |       0.7        |        70.0        |       24.0        |        4.1         |       100.0       |   True    | live  |
# | 126 | 28  | female |  True   |   False    |  True   |  True   |   True   |    nan    |    nan     |      False      |  True   |  True   |  False  |       1.0        | 105.32539682539682 |       20.0        |        4.0         | 61.85227272727273 |   True    | live  |
# | 127 | 50  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      True       |  False  |  True   |  True   |       2.8        |       155.0        |       75.0        |        2.4         |       32.0        |   True    |  die  |
# | 128 | 54  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      False      |  False  |  True   |  False  |       1.2        |        85.0        |       92.0        |        3.1         |       66.0        |   True    | live  |
# | 129 | 57  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      False      |  True   |  True   |  False  |       4.6        |        82.0        |       55.0        |        3.3         |       30.0        |   True    |  die  |
# | 130 | 54  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.0        |        85.0        |       30.0        |        4.5         |        0.0        |   True    | live  |
# | 131 | 31  | female |  False  |   False    |  True   |  True   |   True   |   True    |   False    |      True       |  False  |  False  |  False  |       8.0        | 105.32539682539682 |       101.0       |        2.2         | 61.85227272727273 |   True    |  die  |
# | 132 | 48  | female |  True   |   False    |  True   |  True   |   True   |   True    |    True    |      False      |  True   |  False  |  False  |       2.0        |       158.0        |       278.0       |        3.8         | 61.85227272727273 |   True    | live  |
# | 133 | 72  | female |  True   |    True    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |       1.0        |       115.0        |       52.0        |        3.4         |       50.0        |   True    | live  |
# | 134 | 38  | female |  False  |   False    |  False  |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |       0.4        |       243.0        |       49.0        |        3.8         |       90.0        |   True    |  die  |
# | 135 | 25  | female |  True   |   False    |  True   |  False  |  False   |   False   |    True    |      True       |  True   |  True   |  True   |       1.3        |       181.0        |       181.0       |        4.5         |       57.0        |   True    | live  |
# | 136 | 51  | female |  True   |   False    |  False  |  False  |  False   |   False   |    True    |      False      |  True   |  False  |  False  |       0.8        | 105.32539682539682 |       33.0        |        4.5         | 61.85227272727273 |   True    | live  |
# | 137 | 38  | female |  True   |   False    |  False  |  False  |  False   |   True    |    True    |      False      |  True   |  False  |  True   |       1.6        |       130.0        |       140.0       |        3.5         |       56.0        |   True    | live  |
# | 138 | 47  | female |  True   |   False    |  True   |  True   |  False   |   True    |    True    |      False      |  True   |  True   |  True   |       1.0        |       166.0        |       30.0        |        2.6         |       31.0        |   True    |  die  |
# | 139 | 45  | female |  True   |    True    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.3        |        85.0        |       44.0        |        4.2         |       85.0        |   True    | live  |
# | 140 | 36  | female |  False  |   False    |  True   |  True   |   True   |   False   |    True    |      False      |  True   |  False  |  True   |       1.7        |       295.0        |       60.0        |        2.7         | 61.85227272727273 |   True    | live  |
# | 141 | 54  | female |  False  |   False    |  True   |  True   |  False   |    nan    |    nan     |      True       |  False  |  True   |  False  |       3.9        |       120.0        |       28.0        |        3.5         |       43.0        |   True    |  die  |
# | 142 | 51  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      True       |  True   |  False  |  True   |       1.0        | 105.32539682539682 |       20.0        |        3.0         |       63.0        |   True    | live  |
# | 143 | 49  | female |  False  |   False    |  True   |  True   |  False   |   True    |   False    |      True       |  True   |  False  |  False  |       1.4        |        85.0        |       70.0        |        3.5         |       35.0        |   True    |  die  |
# | 144 | 45  | female |  True   |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  True   |  True   |  False  |       1.9        | 105.32539682539682 |       114.0       |        2.4         | 61.85227272727273 |   True    |  die  |
# | 145 | 31  | female |  False  |   False    |  True   |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       1.2        |        75.0        |       173.0       |        4.2         |       54.0        |   True    | live  |
# | 146 | 41  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      True       |  True   |  False  |  True   |       4.2        |        65.0        |       120.0       |        3.4         | 61.85227272727273 |   True    |  die  |
# | 147 | 70  | female |  False  |   False    |  True   |  True   |   True   |    nan    |    nan     |       nan       |   nan   |   nan   |   nan   |       1.7        |       109.0        |       528.0       |        2.8         |       35.0        |   True    |  die  |
# | 148 | 20  | female |  False  |   False    |  False  |  False  |  False   |   True    |    nan     |      False      |  False  |  False  |  False  |       0.9        |        89.0        |       152.0       |        4.0         | 61.85227272727273 |   True    | live  |
# | 149 | 36  | female |  True   |   False    |  False  |  False  |  False   |   True    |   False    |      False      |  False  |  False  |  False  |       0.6        |       120.0        |       30.0        |        4.0         | 61.85227272727273 |   True    | live  |
# | 150 | 46  | female |  True   |   False    |  True   |  True   |   True   |   True    |   False    |      False      |  True   |  True   |  True   |       7.6        | 105.32539682539682 |       242.0       |        3.3         |       50.0        |   True    |  die  |
# | 151 | 44  | female |  True   |   False    |  True   |  False  |  False   |   True    |    True    |      False      |  False  |  False  |  False  |       0.9        |       126.0        |       142.0       |        4.3         | 61.85227272727273 |   True    | live  |
# | 152 | 61  | female |  False  |   False    |  True   |  True   |  False   |   False   |    True    |      False      |  True   |  False  |  False  |       0.8        |        75.0        |       20.0        |        4.1         | 61.85227272727273 |   True    | live  |
# | 153 | 53  |  male  |  False  |   False    |  True   |  False  |  False   |   True    |   False    |      True       |  True   |  False  |  True   |       1.5        |        81.0        |       19.0        |        4.1         |       48.0        |   True    | live  |
# | 154 | 43  | female |  True   |   False    |  True   |  False  |  False   |   True    |   False    |      True       |  True   |  True   |  False  |       1.2        |       100.0        |       19.0        |        3.1         |       42.0        |   True    |  die  |
# +-----+-----+--------+---------+------------+---------+---------+----------+-----------+------------+-----------------+---------+---------+---------+------------------+--------------------+-------------------+--------------------+-------------------+-----------+-------+
# age                 0
# sex                 0
# steroid             1
# antivirals          0
# fatigue             1
# malaise             1
# anorexia            1
# liver_big          10
# liver_firm         11
# spleen_palpable     5
# spiders             5
# ascites             5
# varices             5
# bilirubin           0
# alk_phosphate       0
# sgot                0
# albumin             0
# protime             0
# histology           0
# class               0
# dtype: int64
